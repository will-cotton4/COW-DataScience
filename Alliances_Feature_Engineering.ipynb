# %%
import numpy as np
import pandas as pd


pd.set_option('display.max_columns', 100)

# %%
dyads_df = pd.read_csv('./data/cleaned_dyads_yearly.csv')
dyads_df.head()
# Out:
#    Unnamed: 0  ccode1     state_name1  ccode2 state_name2  dyad_st_day  \
# 0           0     200  United Kingdom     235    Portugal            1
# 1           1     200  United Kingdom     235    Portugal            1
# 2           2     200  United Kingdom     235    Portugal            1
# 3           3     200  United Kingdom     235    Portugal            1
# 4           4     200  United Kingdom     235    Portugal            1
#
#    dyad_st_month  dyad_st_year  dyad_end_year  left_censor  right_censor  \
# 0              1          1816           2012            1             1
# 1              1          1816           2012            1             1
# 2              1          1816           2012            1             1
# 3              1          1816           2012            1             1
# 4              1          1816           2012            1             1
#
#    defense  neutrality  nonaggression  entente  year
# ...
