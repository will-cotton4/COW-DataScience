# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd


pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Create Datetime Features
#
# 1. Datetime repr. of dyad start date
#
# 2. Datetime repr. of length of alliance

# %%
date_columns = [['dyad_st_year', 'dyad_st_month', 'dyad_st_day']]
dyads_df = pd.read_csv('./data/cleaned_dyads_yearly.csv', parse_dates=date_columns)
dyads_df.head()
# Out:
#   dyad_st_year_dyad_st_month_dyad_st_day  ccode1     state_name1  ccode2  \
# 0                             1816-01-01     200  United Kingdom     235
# 1                             1816-01-01     200  United Kingdom     235
# 2                             1816-01-01     200  United Kingdom     235
# 3                             1816-01-01     200  United Kingdom     235
# 4                             1816-01-01     200  United Kingdom     235
#
#   state_name2  dyad_end_year  left_censor  right_censor  defense  neutrality  \
# 0    Portugal           2012            1             1        1           0
# 1    Portugal           2012            1             1        1           0
# 2    Portugal           2012            1             1        1           0
# 3    Portugal           2012            1             1        1           0
# 4    Portugal           2012            1             1        1           0
#
#    nonaggression  entente  year
# 0            1.0      0.0  1816
# 1            1.0      0.0  1817
# 2            1.0      0.0  1818
# 3            1.0      0.0  1819
# 4            1.0      0.0  1820

# %%
# Rename date column
dyads_df.rename(columns={'dyad_st_year_dyad_st_month_dyad_st_day':'dyad_start_date'}, inplace=True)
dyads_df.head()
# Out:
#   dyad_start_date  ccode1     state_name1  ccode2 state_name2  dyad_end_year  \
# 0      1816-01-01     200  United Kingdom     235    Portugal           2012
# 1      1816-01-01     200  United Kingdom     235    Portugal           2012
# 2      1816-01-01     200  United Kingdom     235    Portugal           2012
# 3      1816-01-01     200  United Kingdom     235    Portugal           2012
# 4      1816-01-01     200  United Kingdom     235    Portugal           2012
#
#    left_censor  right_censor  defense  neutrality  nonaggression  entente  \
# 0            1             1        1           0            1.0      0.0
# 1            1             1        1           0            1.0      0.0
# 2            1             1        1           0            1.0      0.0
# 3            1             1        1           0            1.0      0.0
# 4            1             1        1           0            1.0      0.0
#
#    year
# 0  1816
# 1  1817
# 2  1818
# 3  1819
# 4  1820

# %%
# Convert `dyad_end_year` and `year` to datetime type
